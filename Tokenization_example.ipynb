# %% [markdown]
# <a href="https://colab.research.google.com/github/Auta01/Natural-language-processing-NLP/blob/main/Tokenization_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
corpus = 'hello welcome, to auta nlp tutorial. please do wacth the entire course! to become expert in nlp.'

# %%
print(corpus)
# Out:
# hello welcome, to auta nlp tutorial. please do wacth the entire course! to become expert in nlp.

# %%
##Tokenization
##sentence.....>paragraphs

from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt_tab')
sent_tokenize(corpus)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# ['hello welcome, to auta nlp tutorial.',
#  'please do wacth the entire course!',
#  'to become expert in nlp.']

# %%
##Tokenization
##Paragraph....>words
##Sentence....>words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['hello',
#  'welcome',
#  ',',
#  'to',
#  'auta',
#  'nlp',
#  'tutorial',
#  '.',
#  'please',
#  'do',
#  'wacth',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'nlp',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize
nltk.wordpunct_tokenize(corpus)
# Out:
# ['hello',
#  'welcome',
#  ',',
#  'to',
#  'auta',
#  'nlp',
#  'tutorial',
#  '.',
#  'please',
#  'do',
#  'wacth',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'nlp',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['hello',
#  'welcome',
#  ',',
#  'to',
#  'auta',
#  'nlp',
#  'tutorial.',
#  'please',
#  'do',
#  'wacth',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'nlp',
#  '.']
