# %% [markdown]
# <a href="https://colab.research.google.com/github/Auta01/Natural-language-processing-NLP/blob/main/Lemmatization_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.stem import WordNetLemmatizer

# %%
words =['eat','eaten','eating','write','writen','writing']

# %%
import nltk
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
lemmatizer.lemmatize('going',pos='v')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 'go'

# %%
for word in words:
  print(word+'....'+lemmatizer.lemmatize(word, pos ='v'))
# Out:
# eat....eat
# eaten....eat
# eating....eat
# write....write
# writen....writen
# writing....write
