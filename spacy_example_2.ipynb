# %% [markdown]
# <a href="https://colab.research.google.com/github/Auta01/Natural-language-processing-NLP/blob/main/spacy_example_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 114.6 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

# %%
nlp =  spacy.load('en_core_web_sm')

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7fa5e2a6fe30>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7fa5e2a6fef0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7fa5e28f0890>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7fa5e284ccd0>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7fa5e284da90>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7fa5e28f0970>)]

# %%
doc = nlp('Captain america ate 100$ of samosa. then he said i can do this all day')
for token in doc:
  print(token,'|', token.pos, '|', token.lemma_)
# Out:
# Captain | 96 | Captain
# america | 96 | america
# ate | 100 | eat
# 100 | 93 | 100
# $ | 93 | $
# of | 85 | of
# samosa | 96 | samosa
# . | 97 | .
# then | 86 | then
# he | 95 | he
# said | 100 | say
# i | 95 | I
# can | 87 | can
# do | 100 | do
# this | 95 | this
# all | 90 | all
# day | 92 | day

# %%
doc =nlp('Tesla inc is going to acquire for $45 billion')

for ent in doc.ents:
 print(ent.text, '|', ent.label_,'|',spacy.explain(ent.label))
# Out:
# Tesla inc | ORG | None
# $45 billion | MONEY | None
# /usr/local/lib/python3.12/dist-packages/spacy/glossary.py:20: UserWarning: [W118] Term '383' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /usr/local/lib/python3.12/dist-packages/spacy/glossary.py:20: UserWarning: [W118] Term '394' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))

# %%
from spacy import displacy
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is going to acquire for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $45 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %%
# !python -m spacy download fr_core_news_sm
nlp = spacy.load('fr_core_news_sm')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 98.0 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load('fr_core_news_sm')

# %%
doc =nlp('Tesla inc is going to acquire for $45 billion')

for ent in doc.ents:
 print(ent.text, '|', ent.label_,'|',spacy.explain(ent.label))
# Out:
# Tesla | PER | None
# /usr/local/lib/python3.12/dist-packages/spacy/glossary.py:20: UserWarning: [W118] Term '4317129024397789502' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
