# %% [markdown]
# <a href="https://colab.research.google.com/github/Auta01/Natural-language-processing-NLP/blob/main/Regular_expression_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

# %%
chat1 = 'codebasics: you ask alot of question😘 1234567891, abcxyz.com'
chat2 = 'codebasics: here it is (123)-567-8912, abcxyz.com'
chat3 = 'codebasics yes, phone: 12345678912 email:abcxyz.com'

# %%
pattern = '[a-z]'
matches = re.findall(pattern, chat1)
matches
# Out:
# ['c',
#  'o',
#  'd',
#  'e',
#  'b',
#  'a',
#  's',
#  'i',
#  'c',
#  's',
#  'y',
#  'o',
#  'u',
#  'a',
#  's',
#  'k',
#  'a',
#  'l',
#  'o',
#  't',
#  'o',
#  'f',
#  'q',
#  'u',
#  'e',
#  's',
#  't',
#  'i',
#  'o',
#  'n',
#  'a',
#  'b',
#  'c',
#  'x',
#  'y',
#  'z',
#  'c',
#  'o',
#  'm']
