# %% [markdown]
# <a href="https://colab.research.google.com/github/Auta01/Natural-language-processing-NLP/blob/main/Stemming_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Porterstemmer

# %%
words =['eating', 'eats,','eaten','writing','writes','programming','programs','history','finally','finalize']

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

for word in words:
  print(word+'........'+stemming.stem(word))
# Out:
# eating........eat
# eats,........eats,
# eaten........eaten
# writing........write
# writes........write
# programming........program
# programs........program
# history........histori
# finally........final
# finalize........final

# %%
stemming.stem('Congratulation')
# Out:
# 'congratul'

# %% [markdown]
# Regular Expression Stemmer

# %%
from nltk.stem import RegexpStemmer
reg_stemmer = RegexpStemmer('ing$|s$|able$', min=4)

# %%
reg_stemmer.stem('siting')
# Out:
# 'sit'

# %%
reg_stemmer.stem('ingsiting')
# Out:
# 'ingsit'

# %% [markdown]
# Snowball Stemmer

# %%
##snowballl stemmer
from nltk.stem import SnowballStemmer
snowball = SnowballStemmer('english')

# %%
for word in words:
  print(word+'......'+snowball.stem(word))
# Out:
# eating......eat
# eats,......eats,
# eaten......eaten
# writing......write
# writes......write
# programming......program
# programs......program
# history......histori
# finally......final
# finalize......final
