# %% [markdown]
# <a href="https://colab.research.google.com/github/Auta01/Natural-language-processing-NLP/blob/main/Gensim_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 48.4 MB/s eta 0:00:00
# ...

# %%
import gensim.downloader as api

wv =api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
wv.similarity(w1='profit',w2='loss')
# Out:
# np.float32(0.34199455)

# %%
wv.most_similar('good')
# Out:
# [('great', 0.7291510105133057),
#  ('bad', 0.7190051078796387),
#  ('terrific', 0.6889115571975708),
#  ('decent', 0.6837348341941833),
#  ('nice', 0.6836092472076416),
#  ('excellent', 0.644292950630188),
#  ('fantastic', 0.6407778263092041),
#  ('better', 0.6120728850364685),
#  ('solid', 0.5806034803390503),
#  ('lousy', 0.576420247554779)]

# %%
wv.most_similar(positive=['france', 'berlin'], negative=['paris'])
# Out:
# [('germany', 0.5094343423843384),
#  ('european', 0.48650455474853516),
#  ('german', 0.4714890420436859),
#  ('austria', 0.46964022517204285),
#  ('swedish', 0.4645182490348816),
#  ('Wissenschaft', 0.4532880485057831),
#  ('denmark', 0.4477355480194092),
#  ('München', 0.4438532590866089),
#  ('europe', 0.4420619308948517),
#  ('belgium', 0.43769752979278564)]

# %%
wv.most_similar(positive=['king', 'woman'], negative=['man'])
# Out:
# [('queen', 0.7118193507194519),
#  ('monarch', 0.6189674139022827),
#  ('princess', 0.5902431011199951),
#  ('crown_prince', 0.5499460697174072),
#  ('prince', 0.5377321839332581),
#  ('kings', 0.5236844420433044),
#  ('Queen_Consort', 0.5235945582389832),
#  ('queens', 0.518113374710083),
#  ('sultan', 0.5098593235015869),
#  ('monarchy', 0.5087411403656006)]

# %%
wv.doesnt_match(['dog','cat','lion','microsoft'])
# Out:
# 'microsoft'

# %%
giv = api.load('glove-twitter-25')
# Out:
# [==================================================] 100.0% 104.8/104.8MB downloaded

# %%
giv.most_similar('tesla')
# Out:
# [('qualcomm', 0.9118991494178772),
#  ('motors', 0.907597541809082),
#  ('sachs', 0.8855622410774231),
#  ('alibaba', 0.8841804265975952),
#  ('weber', 0.8666931390762329),
#  ('deere', 0.8601743578910828),
#  ('kernel', 0.8578172922134399),
#  ('foxconn', 0.8552562594413757),
#  ('citigroup', 0.8552471399307251),
#  ('exxon', 0.855033814907074)]
